# %% [markdown]
# # Uninformed Search

# %% [markdown]
# ![Algorithms.png](attachment:Algorithms.png)

# %% [markdown]
# ### Uninformed search is a class of general-purpose search algorithms, used in different data structures, algorithms, and AIs.
# ### these algorithms don’t need to know about the domain/environment in which they are searching for a solution (mostly how far from the goal they are), which is why they are called "uninformed".

# %% [markdown]
# ### In this notebook we're gonna discuss the following uninformed search algorithms:

# %% [markdown]
# 1. Breadth-first Search
# 2. Uniform cost search
# 3. Depth-first Search
# 4. Depth-limited Search
# 5. Iterative deepening depth-first search

# %% [markdown]
# ## [Breadth-First Search](https://en.wikipedia.org/wiki/Breadth-first_search)

# %% [markdown]
# Breadth-first search (BFS) is an algorithm for traversing or searching tree or graph data structures. It starts at the tree root, and explores all of the neighbor nodes at the present depth prior to moving on to the nodes at the next depth level.

# %% [markdown]
# ![BFS](https://upload.wikimedia.org/wikipedia/commons/5/5d/Breadth-First-Search-Algorithm.gif "Breadth-First Search")

# %% [markdown]
# **Completeness:**
#
# this algorithm is complete under the condition of finite branching factor.because it keeps the balance while expanding.
#
# **Time complexity:**
#
# bfs take time O( b<sup>d+1</sup> ), d is graph depth.
# > b + b<sup>1</sup> + b<sup>2</sup> + ... + b<sup>d</sup> + b( b<sup>d</sup> - 1 ) = O( b<sup>d+1</sup> )
#
# **Space complexity:**
#
# the space complexity for this algorithm is O( b<sup>d+1</sup> ), which is exponential, it keeps every node in memory.
#
# **Optimality:**
#
# bfs is not optimal in general, but if `cost per step = 1`, it would be optimal.

# %% [markdown]
# ## Uniform cost search

# %% [markdown]
# also called dijkstra,

# %% [markdown]
# **Completeness:**
#
# this algorithm is complete if every actions cost >
#
# **Time complexity:**
#
#
# **Space complexity:**
#
#
#
# **Optimality:**
#
# yes it is optimal.

# %% [markdown]
# ## [Depth first search](https://en.wikipedia.org/wiki/Depth-first_search)

# %% [markdown]
# Depth first search (dfs) is a graph traversing algorithm that expands nodes in one branch as far (deep) as the branch goes before expanding nodes in other branches.

# %% [markdown]
# ![animated-dfs.gif](attachment:animated-dfs.gif)

# %% [markdown]
# **Completeness:**
#
# this algorithm is complete for graphs and trees in finite spaces (depths), but for graphs with cycles needs to be modified. (e.g. keeping the record of visited nodes to avoid processing a node more than once and/or getting caught in an infinite loop)
#
# **Time complexity:**
#
# dfs take time O(b<sup>m</sup>) which is terrible if m (maximum depth) is much larger than d (goal depth).
#
# **Space complexity:**
#
# the space complexity for this algorithm is O(bm). (linear space!)
#
# **Optimality:**
#
# dfs is not optimal. (the number of steps in reaching the solution may be high)

# %% [markdown]
# ## Depth limited search

# %% [markdown]
# depth limited search is same as dfs, only with a depth limit (depth limited search is limited to depth l, it means that nodes at depth l are considered without child).

# %% [markdown]
# **Completeness:**
#
# this algorithm is not complete, because it will not process nodes at depth deeper than l (depth limit).
#
# **Time complexity:**
#
# O(b<sup>l</sup>)
#
# **Space complexity:**
#
# O(bl)
#
# **Optimality:**
#
# not complete means not optimal!

# %% [markdown]
# ## [Iterative deepening search](https://en.wikipedia.org/wiki/Iterative_deepening_depth-first_search)
